# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize'] = 12,10

# %%
df = pd.read_csv('car.csv')
df.head()
# Out:
#    Unnamed: 0   choice  college  hsg2  coml5   type1   type2   type3    type4  \
# 0           1  choice1        0     0      0     van  regcar     van  stwagon
# 1           2  choice2        1     1      1  regcar     van  regcar  stwagon
# 2           3  choice5        0     1      0  regcar   truck  regcar      van
# 3           4  choice5        0     0      1  regcar   truck  regcar      van
# 4           5  choice5        0     1      0  regcar   truck  regcar      van
#
#     type5  ... cost3 cost4 cost5 cost6 station1 station2 station3  station4  \
# 0     van  ...     6     6     8     8      0.1      0.1      0.3       0.3
# 1  regcar  ...     8     8     4     4      0.0      0.0      0.1       0.1
# 2  regcar  ...     8     8     2     2      0.1      0.1      0.3       0.3
# 3  regcar  ...     2     2     4     4      0.0      0.0      0.7       0.7
# 4  regcar  ...     8     8     2     2      0.3      0.3      0.7       0.7
#
#    station5  station6
# 0       1.0       1.0
# 1       1.0       1.0
# 2       1.0       1.0
# 3       0.1       0.1
# 4       1.0       1.0
#
# [5 rows x 71 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0      college         hsg2        coml5       price1  \
# count  4654.000000  4654.000000  4654.000000  4654.000000  4654.000000
# mean   2327.500000     0.768156     0.221960     0.357757     4.296262
# std    1343.638406     0.422055     0.415609     0.479392     1.912597
# min       1.000000     0.000000     0.000000     0.000000     0.598726
# 25%    1164.250000     1.000000     0.000000     0.000000     3.086326
# 50%    2327.500000     1.000000     0.000000     0.000000     4.138683
# 75%    3490.750000     1.000000     0.000000     1.000000     5.242332
# max    4654.000000     1.000000     1.000000     1.000000    17.370563
#
#             price2       price3       price4       price5       price6  ...  \
# count  4654.000000  4654.000000  4654.000000  4654.000000  4654.000000  ...
# mean      4.296262     4.173241     4.173241     4.149952     4.149952  ...
# std       1.912597     1.909591     1.909591     1.863530     1.863530  ...
# min       0.598726     0.598726     0.598726     0.635196     0.635196  ...
# 25%       3.086326     2.993632     2.993632     2.907212     2.907212  ...
# 50%       4.138683     4.039574     4.039574     4.039574     4.039574  ...
# 75%       5.242332     5.143528     5.143528     5.242332     5.242332  ...
# max      17.370563    17.370563    17.370563    17.370563    17.370563  ...
#
#              cost3        cost4        cost5        cost6     station1  \
# count  4654.000000  4654.000000  4654.000000  4654.000000  4654.000000
# mean      4.954448     4.954448     4.970348     4.970348     0.089514
# std       2.233921     2.233921     2.229181     2.229181     0.190517
# min       2.000000     2.000000     2.000000     2.000000     0.000000
# 25%       2.000000     2.000000     2.000000     2.000000     0.000000
# 50%       4.000000     4.000000     4.000000     4.000000     0.000000
# 75%       6.000000     6.000000     6.000000     6.000000     0.100000
# max       8.000000     8.000000     8.000000     8.000000     0.700000
#
#           station2     station3     station4     station5     station6
# count  4654.000000  4654.000000  4654.000000  4654.000000  4654.000000
# mean      0.089514     0.382768     0.382768     0.823915     0.823915
# std       0.190517     0.253019     0.253019     0.327127     0.327127
# min       0.000000     0.100000     0.100000     0.100000     0.100000
# 25%       0.000000     0.100000     0.100000     0.700000     0.700000
# 50%       0.000000     0.300000     0.300000     1.000000     1.000000
# 75%       0.100000     0.700000     0.700000     1.000000     1.000000
# max       0.700000     0.700000     0.700000     1.000000     1.000000
#
# [8 rows x 58 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4654 entries, 0 to 4653
# Data columns (total 71 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4654 non-null   int64
#  1   choice      4654 non-null   object
#  2   college     4654 non-null   int64
#  3   hsg2        4654 non-null   int64
#  4   coml5       4654 non-null   int64
#  5   type1       4654 non-null   object
#  6   type2       4654 non-null   object
#  7   type3       4654 non-null   object
#  8   type4       4654 non-null   object
#  9   type5       4654 non-null   object
#  10  type6       4654 non-null   object
#  11  fuel1       4654 non-null   object
#  12  fuel2       4654 non-null   object
#  13  fuel3       4654 non-null   object
#  14  fuel4       4654 non-null   object
#  15  fuel5       4654 non-null   object
#  16  fuel6       4654 non-null   object
#  17  price1      4654 non-null   float64
#  18  price2      4654 non-null   float64
#  19  price3      4654 non-null   float64
#  20  price4      4654 non-null   float64
#  21  price5      4654 non-null   float64
#  22  price6      4654 non-null   float64
#  23  range1      4654 non-null   int64
#  24  range2      4654 non-null   int64
#  25  range3      4654 non-null   int64
#  26  range4      4654 non-null   int64
#  27  range5      4654 non-null   int64
#  28  range6      4654 non-null   int64
#  29  acc1        4654 non-null   float64
#  30  acc2        4654 non-null   float64
#  31  acc3        4654 non-null   float64
#  32  acc4        4654 non-null   float64
#  33  acc5        4654 non-null   float64
#  34  acc6        4654 non-null   float64
#  35  speed1      4654 non-null   int64
#  36  speed2      4654 non-null   int64
#  37  speed3      4654 non-null   int64
#  38  speed4      4654 non-null   int64
#  39  speed5      4654 non-null   int64
#  40  speed6      4654 non-null   int64
#  41  pollution1  4654 non-null   float64
#  42  pollution2  4654 non-null   float64
#  43  pollution3  4654 non-null   float64
#  44  pollution4  4654 non-null   float64
#  45  pollution5  4654 non-null   float64
#  46  pollution6  4654 non-null   float64
#  47  size1       4654 non-null   int64
#  48  size2       4654 non-null   int64
#  49  size3       4654 non-null   int64
#  50  size4       4654 non-null   int64
#  51  size5       4654 non-null   int64
#  52  size6       4654 non-null   int64
#  53  space1      4654 non-null   float64
#  54  space2      4654 non-null   float64
#  55  space3      4654 non-null   float64
#  56  space4      4654 non-null   float64
#  57  space5      4654 non-null   int64
#  58  space6      4654 non-null   int64
#  59  cost1       4654 non-null   int64
#  60  cost2       4654 non-null   int64
#  61  cost3       4654 non-null   int64
#  62  cost4       4654 non-null   int64
#  63  cost5       4654 non-null   int64
#  64  cost6       4654 non-null   int64
#  65  station1    4654 non-null   float64
#  66  station2    4654 non-null   float64
#  67  station3    4654 non-null   float64
#  68  station4    4654 non-null   float64
#  69  station5    4654 non-null   float64
#  70  station6    4654 non-null   float64
# dtypes: float64(28), int64(30), object(13)
# memory usage: 2.5+ MB

# %%
X = df[['cost3']].values

# %%
X = X.ravel()

# %%
X
# Out:
# array([6, 8, 8, ..., 4, 4, 2], dtype=int64)

# %%
#equal frequency 
def equifreq(X, m): 
      
    a = len(X) 
    n = int(a / m) 
    for i in range(0, m): 
        arr = [] 
2, 4, 4, 4, 4, 2, 2, 4, 2, 2, 4, 2, 4, 2, 4, 2, 2, 2, 2, 2, 4, 2, 4, 2, 4, 4, 2, 2, 4, 4, 4, 2, 4, 2, 2, 2, 4, 4, 4, 2, 2, 4, 4, 4, 4, 4, 4, 2, 2, 2, 2, 2, 4, 2, 4, 4, 4, 2, 2, 4, 2, 4, 2, 4, 2, 2, 2, 2, 2, 2, 2, 4, 2, 4, 4, 2, 4, 4, 4, 2, 2, 4, 2, 2, 4, 2, 4, 4, 4, 2, 2, 4, 2, 2, 4, 2, 4, 4, 4, 4, 2, 4, 2, 4, 2, 4, 2, 4, 4, 4, 2, 4, 4, 2, 2, 4, 2, 2, 4, 4, 4, 2, 4, 4, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 2, 4, 4, 2, 4, 2, 2, 2, 2, 4, 2, 4, 2, 4, 4, 2, 2, 4, 2, 4, 2, 4, 2, 4, 2, 2, 4, 4, 2, 2, 2, 2, 4, 4, 4, 2, 2, 2, 4, 2, 4, 4, 2, 2, 2, 2, 4, 4, 4, 2, 4, 4, 2, 2, 4, 4, 4, 2, 4, 2, 2, 2, 2, 2, 4, 4, 2, 2, 2, 4, 4, 4, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 4, 2, 4, 4, 4, 4, 2, 2, 2, 4, 4, 2, 4, 4, 2, 2, 2, 4, 4, 4, 2, 4, 2, 2, 4, 2, 4, 4, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 2, 2, 2, 4, 2, 2, 4, 4, 2, 4, 4, 4, 4, 2, 4, 4, 4, 2, 4, 2, 4, 4, 4, 2, 4, 4, 4, 4, 2, 2, 4, 2, 4, 4, 2, 4, 4, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 2, 2, 2, 4, ...

# %% [markdown]
# # Apriori Algo

# %% [markdown]
# Apriori Algorithm is a Machine Learning algorithm which is used to gain insight into the structured relationships between different items involved. The most prominent practical application of the algorithm is to recommend products based on the products already present in the user’s cart.

# %%
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data = pd.read_excel('Online_Retail.xlsx') 
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
#cleaning
# Stripping extra spaces in the description 
data['Description'] = data['Description'].str.strip() 
  
# Dropping the rows without any invoice number 
data.dropna(axis = 0, subset =['InvoiceNo'], inplace = True) 
data['InvoiceNo'] = data['InvoiceNo'].astype('str') 
  
# Dropping all transactions which were done on credit 
data = data[~data['InvoiceNo'].str.contains('C')]

# %%
#splitting
# Transactions done in France 
basket_France = (data[data['Country'] =="France"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo')) 
    
# Transactions done in Portugal 
basket_Por = (data[data['Country'] =="Portugal"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo')) 
  
basket_Sweden = (data[data['Country'] =="Sweden"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo'))

# %%
#hot-encoding

# Defining the hot encoding function to make the data suitable  
# for the concerned libraries 
def hot_encode(x): 
    if(x<= 0): 
        return 0
    if(x>= 1): 
        return 1
  
# Encoding the datasets 
basket_encoded = basket_France.applymap(hot_encode) 
basket_France = basket_encoded 
   
basket_encoded = basket_Por.applymap(hot_encode) 
basket_Por = basket_encoded 
  
basket_encoded = basket_Sweden.applymap(hot_encode) 
basket_Sweden = basket_encoded

# %%
# Building the model 
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules.head()
# Out:
#                                            antecedents  \
# 44                        (JUMBO BAG WOODLAND ANIMALS)
# 259  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 270  (PLASTERS IN TIN WOODLAND ANIMALS, RED TOADSTO...
# 302  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 300  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
#
#                          consequents  antecedent support  consequent support  \
# 44                         (POSTAGE)            0.076531            0.765306
# 259                        (POSTAGE)            0.051020            0.765306
# 270                        (POSTAGE)            0.053571            0.765306
# 302  (SET/6 RED SPOTTY PAPER PLATES)            0.102041            0.127551
# 300    (SET/6 RED SPOTTY PAPER CUPS)            0.102041            0.137755
#
#       support  confidence      lift  leverage  conviction
# 44   0.076531       1.000  1.306667  0.017961         inf
# 259  0.051020       1.000  1.306667  0.011974         inf
# 270  0.053571       1.000  1.306667  0.012573         inf
# 302  0.099490       0.975  7.644000  0.086474   34.897959
# 300  0.099490       0.975  7.077778  0.085433   34.489796

# %%
frq_items = apriori(basket_Por, min_support = 0.05, use_colnames = True) 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules.head()
# Out:
#                               antecedents                         consequents  \
# 1170     (SET 12 COLOUR PENCILS SPACEBOY)  (SET 12 COLOUR PENCILS DOLLY GIRL)
# 1171   (SET 12 COLOUR PENCILS DOLLY GIRL)    (SET 12 COLOUR PENCILS SPACEBOY)
# 1172   (SET OF 4 KNICK KNACK TINS LONDON)  (SET 12 COLOUR PENCILS DOLLY GIRL)
# 1173   (SET 12 COLOUR PENCILS DOLLY GIRL)  (SET OF 4 KNICK KNACK TINS LONDON)
# 1174  (SET OF 4 KNICK KNACK TINS POPPIES)  (SET 12 COLOUR PENCILS DOLLY GIRL)
#
#       antecedent support  consequent support   support  confidence       lift  \
# 1170            0.051724            0.051724  0.051724         1.0  19.333333
# 1171            0.051724            0.051724  0.051724         1.0  19.333333
# 1172            0.051724            0.051724  0.051724         1.0  19.333333
# 1173            0.051724            0.051724  0.051724         1.0  19.333333
# 1174            0.051724            0.051724  0.051724         1.0  19.333333
#
#       leverage  conviction
# 1170  0.049049         inf
# 1171  0.049049         inf
# 1172  0.049049         inf
# 1173  0.049049         inf
# 1174  0.049049         inf

# %%
frq_items = apriori(basket_Sweden, min_support = 0.05, use_colnames = True) 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules.head()
# Out:
#                            antecedents                     consequents  \
# 0        (PACK OF 72 SKULL CAKE CASES)   (12 PENCILS SMALL TUBE SKULL)
# 1        (12 PENCILS SMALL TUBE SKULL)   (PACK OF 72 SKULL CAKE CASES)
# 4       (ASSORTED BOTTLE TOP  MAGNETS)         (36 DOILIES DOLLY GIRL)
# 5              (36 DOILIES DOLLY GIRL)  (ASSORTED BOTTLE TOP  MAGNETS)
# 180  (CHILDRENS CUTLERY CIRCUS PARADE)  (CHILDRENS CUTLERY DOLLY GIRL)
#
#      antecedent support  consequent support   support  confidence  lift  \
# 0              0.055556            0.055556  0.055556         1.0  18.0
# 1              0.055556            0.055556  0.055556         1.0  18.0
# 4              0.055556            0.055556  0.055556         1.0  18.0
# 5              0.055556            0.055556  0.055556         1.0  18.0
# 180            0.055556            0.055556  0.055556         1.0  18.0
#
#      leverage  conviction
# 0    0.052469         inf
# 1    0.052469         inf
# 4    0.052469         inf
# 5    0.052469         inf
# 180  0.052469         inf

# %% [markdown]
# # Apriori

# %%
import pandas as pd
import numpy as np
import math
import itertools
import json


###########
# Load data
###########

adult = pd.read_csv('adult.data', header=None)
adult.columns = ['age', 'workclass','fnlwgt', 'education', 
                'education-num','marital-status','occupation', 'relationship','race',
                'sex','capital-gain','capital-loss','hours-per-week','native-country','income_category']


################
# Pre-processing
################

#drop redundant column
adult = adult.drop("education-num", axis=1) 

#deal with ? entries
columns_with_blank_entries=["workclass","occupation","native-country"] 
for column in columns_with_blank_entries:
    adult["converted_"+column] = adult[column].astype(str).replace(" ", "")+"_"+column
    adult = adult.drop(column, axis=1)
    
#deal with numeric attribures
numeric_columns = ["age","fnlwgt","capital-gain","capital-loss","hours-per-week"] 
for column in numeric_columns:
    bins = np.histogram(adult[column])
    bins = list(bins[1]) #generate 10 equal-width bins
    if(bins[0]==0.0):
        bins[0]=-0.1
    category = pd.cut(adult[column],bins)
    category = category.to_frame()
    category.columns = ['converted_'+column]
    adult = pd.concat([adult,category],axis = 1)
    adult["converted_"+column] = column+"_"+adult["converted_"+column].astype(str).replace(" ", "")
    adult = adult.drop(column, axis=1)
    
#convert to dictionary format for using as an input to the program
dict_table = {}
temp_list=[]
for index, data in adult.iterrows():
    dict_table[str(index)] = data.tolist()
    
def generate_counts_C(candidate_C,dict_table):
    temp_C=[]
    for candidate_itemset in candidate_C:
        temp_C.append({"itemset":candidate_itemset,"support":0})
        for dict_list in dict_table.values(): 
            if(all(x in dict_list for x in candidate_itemset)):
                temp_C[-1]["support"]+=1   
    return temp_C

def has_infrequent_subset(candidate_itemset,set_itemset,k): #make sure all subsets are frequent
    subsets = list(itertools.combinations(candidate_itemset, k-1))
    for x in subsets:
        if(list(x) not in set_itemset):
            return True
    return False

def check_share_condition(itemset_l1,itemset_l2,num_share): #make sure the first k-2 elements are same
    for x in range(num_share):
        if(itemset_l1[x]!=itemset_l2[x]):
            return False
    if(itemset_l1[num_share]>=itemset_l2[num_share]): #violate -> false
        return False
    return True

def generate_candidate_C(set_itemset,k):
    num_share=k-2 
    candidate_C=[]
    for itemset_l1_index, itemset_l1 in enumerate(set_itemset):
        for itemset_l2_index, itemset_l2 in enumerate(set_itemset):
            if(check_share_condition(itemset_l1,itemset_l2,num_share)): #join members of L_{k-1} if their first k-2 items are common
                candidate_itemset=sorted(list(set().union(itemset_l1,itemset_l2))) #join step
                if(has_infrequent_subset(candidate_itemset,set_itemset,k) is False): #prune step
                    candidate_C.append(candidate_itemset)    
    return candidate_C

    
def prune(temp_C, min_sup_count):
    pruned_temp_C = [x for x in temp_C if x["support"] >= min_sup_count]
    pruned_temp_L = sorted([x["itemset"] for x in temp_C if x["support"] >= min_sup_count])
    return pruned_temp_L,pruned_temp_C

def generate_counts_C1(dict_table):
    temp_C=[]
    items = [item for dict_list in dict_table.values() for item in dict_list]
    values, counts = np.unique(items, return_counts=True)
    for x in range(len(values)):
        temp_C.append({"itemset":[values[x]],"support":counts[x]})
    return temp_C

def apriori(dict_table,support):
    L=[]
    C=[]
    min_sup_count = len(dict_table)*support
    
    #generate frequent-1-itemsets. L[0] holds the 1-itemsets, while C[0] holds the 1-itemsets with their support counts
    print("Generating Frequent 1-itemsets")
    counts_C1 = generate_counts_C1(dict_table) #generates candidates for 1-itemsets and their counts
    pruned_L1,pruned_C1 = prune(counts_C1, min_sup_count) #pruning against min_sup
    L.append(pruned_L1)
    for x in pruned_C1:
        x['support']=(float(x['support'])/float(len(dict_table)))
    C.append(pruned_C1)
    
    
    k=2
    while(1):
        print("Generating Frequent "+str(k)+"-itemsets")
        candidate_C = generate_candidate_C(L[k-2],k=k) # same as the 'apriori_gen' procedure in the book
        counts_C = generate_counts_C(candidate_C,dict_table) #find counts
        pruned_L,pruned_C = prune(counts_C, min_sup_count) #prune if support condition is not met
        
        if(not pruned_L): #break if pruned L is an empty set
            break
        
        L.append(pruned_L)
        for x in pruned_C:
            x['support']=(float(x['support'])/float(len(dict_table)))
        C.append(pruned_C)
        k=k+1
    return L,C


################
# Initialization
################

if __name__=='__main__':
    support = 0.23
    L,C = apriori(dict_table,support=support)
    number_of_frequent_itemsets = sum(len(x) for x in L)
    print(" ")
    print("Number of frequent itemsets:")
    print(number_of_frequent_itemsets)
    print(" ")
    print("Frequent itemsets with support: ")
    print(json.dumps(C, indent=4))
# Out:
# Generating Frequent 1-itemsets
# Generating Frequent 2-itemsets
# Generating Frequent 3-itemsets
# Generating Frequent 4-itemsets
# Generating Frequent 5-itemsets
# Generating Frequent 6-itemsets
# Generating Frequent 7-itemsets
# Generating Frequent 8-itemsets
#
# Number of frequent itemsets:
# 581
#
# Frequent itemsets with support:
# [
#     [
#         {
#             "itemset": [
#                 " <=50K"
#             ],
#             "support": 0.7591904425539756
#         },
#         {
#             "itemset": [
#                 " >50K"
#             ],
#             "support": 0.2408095574460244
#         },
#         {
#             "itemset": [
#                 " Female"
#             ],
#             "support": 0.33079450876815825
#         },
#         {
#             "itemset": [
#                 " HS-grad"
#             ],
#             "support": 0.32250238014802984
#         },
#         {
#             "itemset": [
#                 " Husband"
#             ],
#             "support": 0.40517797364945796
#         },
#         {
#             "itemset": [
#                 " Male"
#             ],
#             "support": 0.6692054912318418
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse"
#             ],
#             "support": 0.4599367341297872
#         },
#         {
#             "itemset": [
#                 " Never-married"
#             ],
#             "support": 0.328091889069746
#         },
#         {
#             "itemset": [
#                 " Not-in-family"
#             ],
#             "support": 0.2550597340376524
#         },
#         {
#             "itemset": [
#                 " Private_workclass"
#             ],
#             "support": 0.6970301894904948
#         },
#         {
#             "itemset": [
#                 " United-States_native-country"
#             ],
#             "support": 0.895857006848684
#         },
#         {
#             "itemset": [
#                 " White"
#             ],
#             "support": 0.8542735173981143
#         },
#         {
#             "itemset": [
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.9763520776388932
#         },
#         {
#             "itemset": [
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.953686926077209
#         },
#         {
#             "itemset": [
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.40281318141334727
#         },
#         {
#             "itemset": [
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.47071650133595405
#         },
#         {
#             "itemset": [
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.5446700039925064
#         }
#     ],
#     [
#         {
#             "itemset": [
#                 " <=50K",
#                 " Female"
#             ],
#             "support": 0.29458554712693097
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " HS-grad"
#             ],
#             "support": 0.271060471115752
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male"
#             ],
#             "support": 0.46460489542704464
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Married-civ-spouse"
#             ],
#             "support": 0.2544147907005313
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Never-married"
#             ],
#             "support": 0.31301249961610517
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass"
#             ],
#             "support": 0.5446085808175425
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " United-States_native-country"
#             ],
#             "support": 0.6756242130155707
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " White"
#             ],
#             "support": 0.6356991492890267
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.7587604803292283
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.7366174257547372
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.30361475384662634
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.35954055465126994
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.43312551825803874
#         },
#         {
#             "itemset": [
#                 " Female",
#                 " Private_workclass"
#             ],
#             "support": 0.23807622616013022
#         },
#         {
#             "itemset": [
#                 " Female",
#                 " United-States_native-country"
#             ],
#             "support": 0.29734959000030714
#         },
#         {
#             "itemset": [
#                 " Female",
#                 " White"
#             ],
#             "support": 0.2654095390190719
#         },
#         {
#             "itemset": [
#                 " Female",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.3264641749332023
#         },
#         {
#             "itemset": [
#                 " Female",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.31970762568717176
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 " Private_workclass"
#             ],
#             "support": 0.238936150609625
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 " United-States_native-country"
#             ],
#             "support": 0.29796382174994623
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 " White"
#             ],
#             "support": 0.2734559749393446
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.3194619329873161
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3101870335677651
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male"
#             ],
#             "support": 0.405147262061976
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Married-civ-spouse"
#             ],
#             "support": 0.40490156936212035
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Private_workclass"
#             ],
#             "support": 0.2632597278953349
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " United-States_native-country"
#             ],
#             "support": 0.36427013912349127
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " White"
#             ],
#             "support": 0.3666963545345659
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.3905285464205645
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.37898098952734866
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Married-civ-spouse"
#             ],
#             "support": 0.4090476336721845
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Private_workclass"
#             ],
#             "support": 0.45895396333036453
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country"
#             ],
#             "support": 0.5985074168483769
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " White"
#             ],
#             "support": 0.5888639783790424
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.6498879027056909
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.6339793003900371
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.26679156045575997
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.3132581923159608
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.3510027333312859
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " Private_workclass"
#             ],
#             "support": 0.29888516937440496
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " United-States_native-country"
#             ],
#             "support": 0.4105525014588004
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " White"
#             ],
#             "support": 0.4118423881330426
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.4434446116519763
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.43060716808451827
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.2416387703080372
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " Private_workclass"
#             ],
#             "support": 0.25140505512729955
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " United-States_native-country"
#             ],
#             "support": 0.29418629648966554
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " White"
#             ],
#             "support": 0.26894137157949694
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.3246214796842849
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.31850987377537543
#         },
#         {
#             "itemset": [
#                 " Not-in-family",
#                 " United-States_native-country"
#             ],
#             "support": 0.23119683056417187
#         },
#         {
#             "itemset": [
#                 " Not-in-family",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2495009367034182
#         },
#         {
#             "itemset": [
#                 " Not-in-family",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.24483277540616075
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country"
#             ],
#             "support": 0.618377813949203
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " White"
#             ],
#             "support": 0.5959276434998925
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.6829642824237585
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.6671171032830687
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.27102975952827
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.3370289610269955
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.39461318755566477
#         },
#         {
#             "itemset": [
#                 " United-States_native-country",
#                 " White"
#             ],
#             "support": 0.7868615828752188
#         },
#         {
#             "itemset": [
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.8741746260864224
#         },
#         {
#             "itemset": [
#                 " United-States_native-country",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.853782131998403
#         },
#         {
#             "itemset": [
#                 " United-States_native-country",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.36942968582046004
#         },
#         {
#             "itemset": [
#                 " United-States_native-country",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.41730905070483093
#         },
#         {
#             "itemset": [
#                 " United-States_native-country",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.4808206136175179
#         },
#         {
#             "itemset": [
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.833113233623046
#         },
#         {
#             "itemset": [
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.8132121249347378
#         },
#         {
#             "itemset": [
#                 " White",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.34611959092165473
#         },
#         {
#             "itemset": [
#                 " White",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.4040723565001075
#         },
#         {
#             "itemset": [
#                 " White",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.44789779183686007
#         },
#         {
#             "itemset": [
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.930039003716102
#         },
#         {
#             "itemset": [
#                 "capital-gain_(-0.1, 9999.9]",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.3927704923067473
#         },
#         {
#             "itemset": [
#                 "capital-gain_(-0.1, 9999.9]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.4604895427044624
#         },
#         {
#             "itemset": [
#                 "capital-gain_(-0.1, 9999.9]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.5361321826725224
#         },
#         {
#             "itemset": [
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.3832499001873407
#         },
#         {
#             "itemset": [
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.4494333712109579
#         },
#         {
#             "itemset": [
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.5216363133810387
#         },
#         {
#             "itemset": [
#                 "fnlwgt_(159527.0, 306769.0]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.2599735880347655
#         }
#     ],
#     [
#         {
#             "itemset": [
#                 " <=50K",
#                 " Female",
#                 " United-States_native-country"
#             ],
#             "support": 0.2644267682196493
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Female",
#                 " White"
#             ],
#             "support": 0.23383802708762016
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Female",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.29446270077700315
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Female",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.2866005343816222
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " HS-grad",
#                 " United-States_native-country"
#             ],
#             "support": 0.2493473787660084
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " HS-grad",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2709069131783422
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " HS-grad",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.2630447467829612
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 " Private_workclass"
#             ],
#             "support": 0.328828967169313
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 " United-States_native-country"
#             ],
#             "support": 0.4111974447959215
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 " White"
#             ],
#             "support": 0.4018611222014066
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.46429777955222507
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.45001689137311507
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.2592672215226805
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Married-civ-spouse",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2541383864131937
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Married-civ-spouse",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.24606123890543902
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Never-married",
#                 " Private_workclass"
#             ],
#             "support": 0.24133165443321766
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Never-married",
#                 " United-States_native-country"
#             ],
#             "support": 0.28042750529774885
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Never-married",
#                 " White"
#             ],
#             "support": 0.2557661005497374
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Never-married",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.31288965326617735
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Never-married",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.30475108258345873
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass",
#                 " United-States_native-country"
#             ],
#             "support": 0.47891649519363655
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass",
#                 " White"
#             ],
#             "support": 0.45674272903166363
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.5444243112926507
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.529252787076564
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.26458032615705906
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.32320874666011484
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " United-States_native-country",
#                 " White"
#             ],
#             "support": 0.5809711003961795
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.6752249623783053
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " United-States_native-country",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.6552010073400694
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " United-States_native-country",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.2786769448112773
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " United-States_native-country",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.31525444550228804
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " United-States_native-country",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.3802401646141089
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.6353306102392433
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.6163201375879119
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " White",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.25567396578729157
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " White",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.3027855409846135
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " White",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.3499278277694174
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.7361874635299899
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.30346119590921655
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.35929486195141425
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.43294124873314704
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.29375633426491815
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.34912932649488654
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.42001167040324316
#         },
#         {
#             "itemset": [
#                 " Female",
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.23540431804919995
#         },
#         {
#             "itemset": [
#                 " Female",
#                 " Private_workclass",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.23070544516446054
#         },
#         {
#             "itemset": [
#                 " Female",
#                 " United-States_native-country",
#                 " White"
#             ],
#             "support": 0.24470992905623293
#         },
#         {
#             "itemset": [
#                 " Female",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2932956604526888
#         },
#         {
#             "itemset": [
#                 " Female",
#                 " United-States_native-country",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.2871533429562974
#         },
#         {
#             "itemset": [
#                 " Female",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.261785571696201
#         },
#         {
#             "itemset": [
#                 " Female",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.2559503700746292
#         },
#         {
#             "itemset": [
#                 " Female",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.31537729185221586
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.23733914806056325
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 " Private_workclass",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.23064402198949663
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 " United-States_native-country",
#                 " White"
#             ],
#             "support": 0.257485949448727
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.29516906728908815
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 " United-States_native-country",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.28620128374435677
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.27084549000337826
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.26258407297073183
#         },
#         {
#             "itemset": [
#                 " HS-grad",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3071465864070514
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " Married-civ-spouse"
#             ],
#             "support": 0.4048708577746384
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " Private_workclass"
#             ],
#             "support": 0.26322901630785295
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " United-States_native-country"
#             ],
#             "support": 0.36423942753600935
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " White"
#             ],
#             "support": 0.3666656429470839
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.39049783483308254
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3789502779398667
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Married-civ-spouse",
#                 " Private_workclass"
#             ],
#             "support": 0.26307545837044316
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Married-civ-spouse",
#                 " United-States_native-country"
#             ],
#             "support": 0.36399373483615366
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Married-civ-spouse",
#                 " White"
#             ],
#             "support": 0.3664199502472283
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Married-civ-spouse",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.39025214213322684
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Married-civ-spouse",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.37870458524001105
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Private_workclass",
#                 " United-States_native-country"
#             ],
#             "support": 0.2342372777248856
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Private_workclass",
#                 " White"
#             ],
#             "support": 0.23770768711034673
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2549675992752065
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Private_workclass",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.24704400970486165
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " United-States_native-country",
#                 " White"
#             ],
#             "support": 0.3394551764380701
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.35081846380639414
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " United-States_native-country",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.34053008199993856
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.353091121280059
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3428027394736034
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3643315622984552
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Married-civ-spouse",
#                 " Private_workclass"
#             ],
#             "support": 0.2662080402936028
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Married-civ-spouse",
#                 " United-States_native-country"
#             ],
#             "support": 0.36691133564693956
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Married-civ-spouse",
#                 " White"
#             ],
#             "support": 0.36964466693283377
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Married-civ-spouse",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.3943674948558091
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Married-civ-spouse",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3827892263751113
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Private_workclass",
#                 " United-States_native-country"
#             ],
#             "support": 0.40566935904916923
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Private_workclass",
#                 " White"
#             ],
#             "support": 0.40302816252572093
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.4475599643745585
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Private_workclass",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.43641165811860816
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Private_workclass",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.25238782592672215
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 " White"
#             ],
#             "support": 0.5421516538189859
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.5808789656337336
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.5666287890421056
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.24504775651853444
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.27778630877430055
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.3078529529191364
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.571327661926845
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.5572617548601088
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " White",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.23663278154847825
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " White",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.2776020392494088
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " White",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.298854457786923
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.6146617118638863
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.25865298977304135
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.3049353521083505
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.3446454347225208
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.2526028070390959
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.29667393507570405
#         },
#         {
#             "itemset": [
#                 " Male",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.33429562974110133
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " Private_workclass",
#                 " United-States_native-country"
#             ],
#             "support": 0.2638432480574921
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " Private_workclass",
#                 " White"
#             ],
#             "support": 0.26669942569331406
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2895181351924081
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " Private_workclass",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.2809496022849421
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " United-States_native-country",
#                 " White"
#             ],
#             "support": 0.3798716255643254
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.39547311200515955
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " United-States_native-country",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3840176898743896
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.39676299867940173
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.38512330702374004
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.4141150456067074
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.2358649918614293
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2490709744786708
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " Private_workclass",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.24455637111882314
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " United-States_native-country",
#                 " White"
#             ],
#             "support": 0.24765824145450077
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2910537145665059
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " United-States_native-country",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.28543349405730783
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2661159055311569
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.26101778200915204
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3150394643899143
#         },
#         {
#             "itemset": [
#                 " Not-in-family",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.23927397807192655
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White"
#             ],
#             "support": 0.5444550228801327
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.6054789472067811
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.5910137895027794
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.2469211633549338
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.2964589539633304
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.3433862596357606
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.583428027394736
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.5692085623905899
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " White",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.2324560056509321
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " White",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.29019379011701113
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " White",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.3260342127084549
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.6530511962163325
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.26488744203187864
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.3311016246429778
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.38982217990847945
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.25831516231073987
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.3232701698350788
#         },
#         {
#             "itemset": [
# ...
#             ],
#             "support": 0.23912042013451676
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.2573323915113172
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.2552132919750622
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.2871840545437794
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.2550597340376524
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.27907619544854273
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2358649918614293
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " Private_workclass",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.23896686219710697
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " Private_workclass",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.24191517459537484
#         },
#         {
#             "itemset": [
#                 " Married-civ-spouse",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.34034581247504686
#         },
#         {
#             "itemset": [
#                 " Never-married",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.23740057123552716
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.5072632904394828
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.25751666103620896
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.28985596265470964
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.25097509290255215
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.2815945456220632
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.2785233868738675
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.32563496207118947
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.27256533890236784
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.3095113786431621
#         },
#         {
#             "itemset": [
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.30346119590921655
#         },
#         {
#             "itemset": [
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.34139000644943335
#         },
#         {
#             "itemset": [
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.38205214827554435
#         }
#     ],
#     [
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.2542612327631215
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.2459383925555112
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 " Private_workclass",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.277448481311999
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 " Private_workclass",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.2745615920886951
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3534903719173244
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.40032554282730876
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.23436012407481344
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.27155185651546326
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " Private_workclass",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.25558183102484566
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(12285.0, 159527.0]"
#             ],
#             "support": 0.23454439359970516
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.26375111329504625
#         },
#         {
#             "itemset": [
#                 " <=50K",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.3053346027456159
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " Married-civ-spouse",
#                 " Private_workclass",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.23853689997235958
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " Married-civ-spouse",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]"
#             ],
#             "support": 0.32621848223334665
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " Married-civ-spouse",
#                 " United-States_native-country",
#                 " White",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3165443321765302
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " Married-civ-spouse",
#                 " United-States_native-country",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.32677129080802186
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " Married-civ-spouse",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3288903903442769
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.30389115813396395
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Married-civ-spouse",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.3036454654341083
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Married-civ-spouse",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.30610239243266485
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.33819600135130984
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.23190319707625687
#         },
#         {
#             "itemset": [
#                 " Male",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.25211142163938455
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "fnlwgt_(159527.0, 306769.0]"
#             ],
#             "support": 0.2459383925555112
#         },
#         {
#             "itemset": [
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]",
#                 "hours-per-week_(30.4, 40.2]"
#             ],
#             "support": 0.2778784435367464
#         }
#     ],
#     [
#         {
#             "itemset": [
#                 " <=50K",
#                 " Male",
#                 " Private_workclass",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.2458769693805473
#         },
#         {
#             "itemset": [
#                 " Husband",
#                 " Male",
#                 " Married-civ-spouse",
#                 " United-States_native-country",
#                 " White",
#                 "capital-gain_(-0.1, 9999.9]",
#                 "capital-loss_(-0.1, 435.6]"
#             ],
#             "support": 0.30361475384662634
#         }
#     ]
# ]
